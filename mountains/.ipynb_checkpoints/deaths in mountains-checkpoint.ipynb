# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import geopandas as gpd 
import matplotlib.pyplot as plt
# import folium 
from shapely.ops import nearest_points
from shapely.geometry import LineString
import rasterio

# %%
mountains = rasterio.open('../migrant_deaths_analysis/mountains/mtn_02g')



mountains.crs
# Out:
# CRS.from_epsg(4326)

# %%
deaths = gpd.read_file("../migrant_deaths/deaths/ogis_migrant_deaths_091021_with_yuma.geojson")

deaths=deaths[deaths['Latitude'].notnull()]
deaths['Latitude']= deaths.Latitude.astype(float)
deaths['Longitude']= deaths.Longitude.astype(float)
deaths = gpd.GeoDataFrame(deaths, geometry=gpd.points_from_xy(deaths.Longitude,deaths.Latitude))
print(len(deaths))


deaths = deaths.set_crs('epsg:4326')
# deaths = deaths.to_crs('+proj=robin +lon_0=0 +x_0=0 +y_0=0 +a=6371000 +b=6371000 +units=m no_defs')
deaths['Reporting Date']= pd.to_datetime(deaths['Reporting Date'])
deaths['Reporting_year']= pd.to_datetime(deaths['Reporting Date']).dt.year



print(deaths.total_bounds)

print(deaths.total_bounds[0])
print(deaths.total_bounds[1])
# Out:
# 3912
# [-114.80891    31.33271  -109.053383   33.94276 ]
# -114.80891
# 31.33271

# %%
# distances1 = 
# min_idx1 = distances1.idxmin()

# distances1

def if_mountain(row):
    
#     print(row['index'])

#     x,y=row['geometry'].coords.xy
#     list_val = []
#     var = .sample()
    
#     print(var)
         
#     value = mountains.sample((row['geometry'].x, row['geometry'].y))
# #     print(value) 
    
#     for val in value:
#         print(val)
        
    for val in mountains.sample([(row['geometry'].x, row['geometry'].y)]): 
#         print(val)
        if val[0] == 255:
            return 0
        else:
            return val[0]
      

    
# deaths['values'] = [sample[0] for sample in mountains.sample([deaths['geometry'].x,deaths['geometry'].y])]
    
# coords = [(x,y) for x, y in zip(pts.UTM_E, pts.UTM_N)]

# deaths['mountains'] = [x for x in mountains.sample(coords)]
    
#     print( row['geometry'][0])

deaths['mountains'] = deaths.apply(lambda row : if_mountain(row),axis=1)
                                      
deaths['mountains']= pd.to_numeric(deaths['mountains'])                        
deaths
# Out:
#      ML Number                           Name     Sex Age Reporting Date  \
# 0     00-00097                   Unidentified    male         2000-01-10
# 1     00-00148                 Nicolas, Tomas    male  17     2000-01-22
# 2     00-00189                   Unidentified    male         2000-01-20
# 3     00-00222                   Unidentified    male         2000-01-10
# 4     00-00245  Candia-Bravo, Maria Del Rocio  female  20     2000-02-05
# ...        ...                            ...     ...  ..            ...
# 3909      None                           None    male  22     2021-08-31
# 3910      None                           None  female  37     2021-09-10
# 3911      None                           None  female  42     2021-09-10
# 3912      None                           None    male  33     2021-09-10
# 3913      None                           None  female  28     2021-09-10
#
#               Surface Management Location  \
# 0     Cocopah Indian Reservation
# ...

# %%
deaths.to_csv('deaths_mountains.csv')

# %%
# deaths1 = gpd.read_file("../migrant_deaths/deaths/sample.csv")
# deaths1

# merged_deaths = deaths1.merge(deaths, on='ML Number')

# mountain_vals = merged_deaths[['mountains','rvalue_1']]

# def if_mou(row):
#     if row['rvalue_1'] =='':
# #         print(True)
#         return 0
#     else:
#         return row['rvalue_1']
    
# def if_mou1(row):
#     if row['rvalue_1'] == row['mountains']:

#         return True
#     else:
#         return False

# mountain_vals['rvalue_1'] = mountain_vals.apply(lambda row : if_mou(row),axis=1)

# mountain_vals['rvalue_1'] = pd.to_numeric(mountain_vals['rvalue_1'])
# mountain_vals['mountains']= pd.to_numeric(mountain_vals['mountains'])

# mountain_vals['same'] = mountain_vals.apply(lambda row : if_mou1(row),axis=1)
# # print(type(mountain_vals['rvalue_1'][0]))

# # mountain_vals['mountains'] = deaths.apply(lambda row : if_mountain(row),axis=1)
# mountain_vals['same'].value_counts(dropna=False)

# mountain_vals[mountain_vals['same']==False]
